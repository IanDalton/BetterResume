# %%
JOB_PROMPT = """🚀 Join Our Data Products and Machine Learning Development Remote Startup!

🚀Mutt Data is a dynamic startup committed to crafting innovative systems using cutting-edge Big Data and Machine Learning technologies.

We’re looking for a Machine Learning Engineer to help take our expertise to the next level. If you consider yourself a data nerd like us, we’d love to connect! 🐶🚀

🚀 What We Do:
- Leveraging our expertise, we build modern Machine Learning systems for demand planning and budget forecasting.
- Developing scalable data infrastructures, we enhance high-level decision-making, tailored to each client.
- Offering comprehensive Data Engineering and custom AI solutions, we optimize cloud-based systems.
- Using Generative AI, we help e-commerce platforms and retailers create higher-quality ads, faster.

🌟 Our Partnerships:
- Amazon Web Services
- Google Cloud
- Astronomer
- Kaszek
- Product Minds
- H2O.ai
- Soda

🌟 Our values:
📊 We are Data Nerds
🤗 We are Open Team Players
🚀 We Take Ownership
🌟 We Have a Positive Mindset

🔍 Curious about what we’re up to? Check out our case studies and dive into our blog post to learn more about our culture and the exciting projects we’re working on! 🚀

Responsibilities 🤓

- Develop and optimize ML models, ensuring scalability, monitoring, and integration with MLOps best practices.
- Implement client requirements, from exploratory data analysis (EDA) to feature engineering and model lifecycle management.
- Build ML Proof of Concepts (POCs) to validate and refine solutions.
- Optimize models for performance, latency, memory, and throughput.
- Apply statistical analysis techniques and develop regression models.
- Design and maintain feature stores and data pipelines for ML workflows.
- Research and implement emerging ML/AI techniques to enhance solutions.
- Collaborate with stakeholders to align technical solutions with business needs.


We don’t expect you to check every box, but here’s what we’re looking for:

Required Skills 💻

✓ Proven Experience: Experience as ML Engineer
✓ AI/ML Expertise: Solid understanding of ML models, deep learning, and statistical analysis.
✓ Tech Stack Know-How: Experience with MLOps tools (Airflow, MLflow, DBT) and cloud services (AWS, GCP).
✓ Programming Skills: Strong in Python and at least one other language.
✓ MLOps: Experience managing model lifecycles and setting up CI/CD pipelines.
✓ Collaboration: Team player with strong communication skills.
✓ Languages: Intermediate English, Advanced Spanish.

Nice to Have 🧠

✓ Modern Data Stack: Familiar with tools like Kafka, DuckDB, Apache Pinot.
✓ Cloud AI Services: Hands-on with AWS Sagemaker, GCP Vertex AI.
✓ Software Development: Experience with software engineering practices.
✓ Problem-Solver: Positive, proactive attitude towards challenges.
✓ Consulting Experience: Worked in client-facing roles.
✓ Cloud Certifications: AWS, GCP, or related certifications.
✓ Python Libraries: Experience with libraries like SQLAlchemy, Great Expectations.

🏆 Why Join Us?

At Mutt Data, we offer a remote-first culture with flexibility, autonomy, and awesome benefits:

💵 Salary in USD (up to 20% bonus).
🏡 Remote-First Culture
🏋️‍♂️ Gympass or sport club stipend.
📚 Paid AWS & Databricks Certifications.
🍔 Food credits via Pedidos Ya.
🎂 Birthday off + extra vacation week (Mutt Week!).
👥 Referral bonuses to grow our team.
✈️ Annual Mutters' Trip – Join us for an unforgettable team trip!

Even if you don’t meet every requirement, we’d love to hear from you! Let us know why you think Mutt Data is the next step in your journey.

Apply now and join a team that’s shaping the future of Machine Learning and Data Engineering. 🤖"""

JOB_PROMPT_SPANISH = """
¿Te apasionan los desafíos y tu objetivo es dar la milla extra siempre? 🚀



Si tienes ganas de trabajar junto a un gran equipo y afrontar nuevos retos, esta es tu oportunidad!



Estamos en la búsqueda de un/a Data Engineer



✔ ¿Qué conocimientos/experiencia necesitas?



Estudiantes promediando o avanzados en carreras universitarias o terciarias de Ingeniería en Sistemas, Licenciaturas o afines o idóneo.
Experiencia trabajando con base de datos (SQL y No SQL) y/o en el área Big Data.
Conocimiento intermedio de APIs (consulta y creación)
Conocimiento intermedio de base de datos (SQL y NO SQL)
Experiencia como Full Stack DBA
Conocimiento y experiencia en herramientas de visualización (Power BI, Qlik Sence, Microstrategy, Tableau, R/ Phyton)
Conocimiento básico de framework (Apache Spark, Hadoop


➡Si estás en la búsqueda de un cambio en tu carrera que sume a tu perfil profesional ven a trabajar a nuestro equipo!



Contáctanos!"""

NICO_PROMPT = """
Programador de Videojuegos – Ref: 22-520
Empresa: Tlön Industries
Posición a cubrir: Programador de Videojuegos - Tiempo Completo - Híbrido/Remoto
Descripción del empleo:
Estamos en la búsqueda de un experimentado desarrollador para que se una al equipo y nos ayude a encontrar, abordar y resolver los distintos desafíos que se presentan en el desarrollo de nuestro título principal, Per Aspera, como también para nuevos proyectos aún sin anunciar. Es mandatorio tener experiencia comprobable habiendo trabajado como programador en la industria de desarrollo de videojuegos. Si tienes conocimientos generales y/o experiencia en otras áreas es un plus.

Responsabilidades:
Ayudar a crear y desarrollar arquitecturas de código robustas y efectivas.
Leer, revisar y mejorar el código de otros devs.
Programar mecánicas del juego en Unity Engine.
Escribir la documentación técnica relacionada.
Anticipar problemas técnicos y proponer las posibles soluciones.
Investigar y especializarse en diferentes áreas técnicas de programación.
Trabajar en conjunto con diseñadores y artistas.
Ayuda a mejorar el flujo de trabajo de nuestro equipo de ingeniería.

Lo que ofrecemos
Horarios de trabajo flexibles.
Modalidad de trabajo híbrida (oficina/remoto) o totalmente remota para candidatos que demuestren capacidades y condiciones remarcables.
Celebramos y promovemos la diversidad, inclusión y respeto.
Flexibilidad en el foco de tu carrera. Si te interesan otras áreas de desarrollo, nosotros vamos a facilitar y darte apoyo para que desarrolles esas habilidades.
Programa de referidos. Incentivamos la recomendación de nuevos talentos.
Requerimientos excluyentes:
Maestría en el uso de Unity Engine + C#.
2+ años de experiencia desarrollando juegos.
Muy buen manejo del idioma inglés, tanto oral como escrito.
Habilidades de programación fuertemente orientadas hacia la programación de objetos.
Experiencia con sistemas de control de versionado.
Tener un entendimiento claro de los procesos de desarrollo de un juego.
Ser proactivo, auto-organizado y orientado principalmente a la resolución de problemas.

Requerimientos no excluyentes:
Bonus
Experiencia trabajando con metodologías Ágiles.
Experiencia trabajando en VR.
Capacidad de tomar la iniciativa.
Experiencia perfilando UI y optimizando (CPU y GPU).
Conocimiento de los formatos de imágenes/texturas, su compresión y shaders.
Experiencia con C++.

Edad: No aplica

Lugar de trabajo: CABA - Hibrido/Remoto
"""

# %%
from resume import Resume

r = Resume(NICO_PROMPT)

# %%
""" exp = {'language': 'EN',
 'resume_section': {'title': 'Unity Developer',
  'professional_summary': 'Experienced Unity Developer with proven expertise in full-cycle game development using C#. Skilled in building game engines, prototypes, and implementing efficient code for both PC and mobile platforms. Adept at utilizing APIs, libraries, and Scriptable Objects to enhance game functionality and performance. Collaborative team player passionate about solving complex problems and delivering high-quality gaming experiences.',
  'experience': [{'position': 'Lead Programmer',
    'company': 'Fernobite',
    'location': 'Argentina',
    'start_date': '01/10/2024',
    'end_date': 'Present',
    'description': 'Developed and integrated all game and ludic features for online and offline gameplay, leveraging Scriptable Objects for versatile and future-proof code. Created internal development tools to streamline data input and testing processes. Collaborated effectively in Agile sprints, contributing to improved system efficiency and performance.'},
   {'position': 'C# Developer',
    'company': 'ABI RACHED STUDIOS',
    'location': 'Argentina',
    'start_date': '01/03/2024',
    'end_date': '01/07/2024',
    'description': "Developed and integrated the foundational structure of the game's back-end, including input systems, micro services, events, and enemy AI. Utilized Scriptable Objects for adaptable code and future content integration. Collaborated effectively in Agile sprints to enhance system efficiency and performance."},
   {'position': 'Main Programmer',
    'company': 'Freelance',
    'location': 'Argentina',
    'start_date': '01/12/2024',
    'end_date': 'Present',
    'description': 'Developed games for PC and mobile platforms for clients worldwide as a freelance programmer.'}],
  'skills': [{'name': 'Unity Development',
    'description': 'Extensive experience in developing games using Unity engine, proficient in C# scripting and game mechanics implementation.'},
   {'name': 'Scriptable Objects',
    'description': 'Expertly utilizes Scriptable Objects to create reusable and adaptable code for efficient game development and future content integration.'},
   {'name': 'Game Engine Architecture',
    'description': 'Skilled in designing and building robust game engine foundations, including core systems, input handling, and gameplay logic.'},
   {'name': 'API Integration',
    'description': 'Experienced in integrating various APIs and libraries to enhance game functionality and performance.'},
   {'name': 'Agile Development',
    'description': 'Collaborative team player with experience working in Agile sprints, contributing to efficient project delivery and continuous improvement.'}]}}
r.response = exp """
r.generate_resume()
# Out:
# chatbot message
# tools message
# {'query': 'Unity Engine, C#, game development experience'}
# chromadb
# ...

# %%
r.response
# Out:
# {'language': 'ES',
#  'resume_section': {'title': 'Programador de Videojuegos',
#   'professional_summary': 'Desarrollador de C# con experiencia en desarrollo de videojuegos, experto en Unity Engine y metodologías ágiles. Capacidad comprobada para diseñar arquitecturas robustas, integrar características de juego y optimizar el rendimiento. Jugador de equipo colaborativo con pasión por la resolución de problemas y aprendizaje continuo.',
#   'experience': [{'position': 'Programador Líder',
#     'company': 'Fernobite',
#     'location': 'Argentina',
#     'start_date': 'Octubre 2024',
#     'end_date': 'Presente',
#     'description': 'Desarrolló e integró todas las características lúdicas y de juego para partidas en línea y fuera de línea, utilizando Scriptable Objects para mejorar la versatilidad del código. Creó herramientas de desarrollo dentro de Unity para optimizar la entrada de datos y pruebas, contribuyendo a una mayor eficiencia del sistema mediante sprints ágiles.'},
# ...
