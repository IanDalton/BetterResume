# %%
JOB_PROMPT = """Technology is our how. And people are our why. For over two decades, we have been harnessing technology to drive meaningful change.

By combining world-class engineering, industry expertise and a people-centric mindset, we consult and partner with leading brands from various industries to create dynamic platforms and intelligent digital experiences that drive innovation and transform businesses.

From prototype to real-world impact - be part of a global shift by doing work that matters.

Job Description

Our data team has expertise across engineering, analysis, architecture, modeling, machine learning, artificial intelligence, and data science. This discipline is responsible for transforming raw data into actionable insights, building robust data infrastructures, and enabling data-driven decision-making and innovation through advanced analytics and predictive modeling.

As a data analyst at Endava I will be able to

 Business Questions:
Figuring out what the underlying business problems are and how to understand them with data.
 Visualisation:
Turning data into charts and graphs to explain insights.
 Statistics:
Quantifying the significance of observed patterns and trends.
 Deep Domain Knowledge (Advanced):
Understanding industry drivers.

Typical output:
Presentations to inform a management decision.

Typical Technologies:
Jupyter Notebook, Pandas, Matplotlib

Typical Degree:
Business, Economics, Psychology, Anything.

A good data analyst should be able engage with these questions:


 How do you identify what business problems are the most important to address?
 What makes an effective plot or chart?
 Explain the difference between a sample and a population. How does that matter when applying the Central Limit Theorem?
 Explain what matters in [your chosen industry] in 50 words.

Qualifications

Demonstrated experience in Storytelling with data. 
Proficient in visualization tools such as PowerBI or Tableau
Proficient in SDLC (Planned Iterative, Agile).
Excellent spoken and written English language skills.
Solid understanding of programming languages.
Solid knowledge of big data technologies.
Solid experience in large international projects working with multicultural teams.

Additional Information

Discover some of the global benefits that empower our people to become the best version of themselves:


Finance:
Competitive salary package, share plan, company performance bonuses, value-based recognition awards, referral bonus; 
Career Development:
Career coaching, global career opportunities, non-linear career paths, internal development programmes for management and technical leadership;
Learning Opportunities:
Complex projects, rotations, internal tech communities, training, certifications, coaching, online learning platforms subscriptions, pass-it-on sessions, workshops, conferences;
Work-Life Balance:
Hybrid work and flexible working hours, employee assistance programme;
Health:
Global internal wellbeing programme, access to wellbeing apps;
Community:
Global internal tech communities, hobby clubs and interest groups, inclusion and diversity programmes, events and celebrations.

Our diversity makes us stronger - it drives meaningful change and enables us to build innovative technology solutions. We are committed to creating an inclusive community where all of us, regardless of background, identity, or personal characteristics, feels valued, respected, and free from discrimination. As an equal opportunity employer, we welcome applications from all individuals and base hiring decisions on merit, skills, qualifications, and potential."""

JOB_PROMPT_SPANISH = """¿Quiénes somos?

Somos la empresa de tecnología y negocios más prestigiosa de Iberoamérica. Nuestra red regional permite responder rápidamente a la demanda, con especialistas en cada problemática y aplicando innovación tecnológica a cada negocio.



📢 ¿Qué buscamos?

Nos encontramos en la búsqueda de Data Scientist.





📢 ¿Qué tareas deberá hacer el perfil que se sume?

Desarrollo con Python y/o R.
Conocimiento de librerías como pandas y sklearn. También librerías de visualización, como matplotlib, pyplot, seaborn.
Lenguaje de consulta SQL.
Aplicar las siguientes técnicas: modelos de regresión, clasificación, series temporales, árboles, ensambles, redes neuronales, técnicas de clustering y reducción de dimensionalidad.




¿Qué necesitamos? 💪



2 años de experiencia como científico/a de datos.
Experiencia en trabajo en modelos predictivos.
Experiencia en IA Generativa.
Deseable experiencia en metodologías ágiles.
Poseer conocimientos sobre modelos supervisados y no supervisados, evaluación de modelos, balanceo de datos.
Tener conocimientos en temas de machine learning.
Conocimiento de estadística básica aplicada a Ciencia de Datos
Capacidad de transmisión de conocimientos y presentación de resultados de forma asertiva
Conocimiento de buenas prácticas de programación
Manejo de plataformas Cloud (preferentemente Azure)


♥ ¿Qué beneficios te ofrecemos?

Licencia extendida para días de estudio.
Días de licencia personal para usar como más te guste.
Días de home office.
La posibilidad de crecer profesionalmente en un ambiente dinámico y flexible.
Formación profesional relacionada con el perfil.
Capacitación en herramientas de gestión, liderazgo y tecnologías.
Descuentos en Universidades e Instituciones Tecnológicas para Maestrías, Postgrados y Cursos.
Clases de Inglés In company.
Prepaga de primer nivel para el grupo familiar.
"""

NICO_PROMPT = """
Programador de Videojuegos – Ref: 22-520
Empresa: Tlön Industries
Posición a cubrir: Programador de Videojuegos - Tiempo Completo - Híbrido/Remoto
Descripción del empleo:
Estamos en la búsqueda de un experimentado desarrollador para que se una al equipo y nos ayude a encontrar, abordar y resolver los distintos desafíos que se presentan en el desarrollo de nuestro título principal, Per Aspera, como también para nuevos proyectos aún sin anunciar. Es mandatorio tener experiencia comprobable habiendo trabajado como programador en la industria de desarrollo de videojuegos. Si tienes conocimientos generales y/o experiencia en otras áreas es un plus.

Responsabilidades:
Ayudar a crear y desarrollar arquitecturas de código robustas y efectivas.
Leer, revisar y mejorar el código de otros devs.
Programar mecánicas del juego en Unity Engine.
Escribir la documentación técnica relacionada.
Anticipar problemas técnicos y proponer las posibles soluciones.
Investigar y especializarse en diferentes áreas técnicas de programación.
Trabajar en conjunto con diseñadores y artistas.
Ayuda a mejorar el flujo de trabajo de nuestro equipo de ingeniería.

Lo que ofrecemos
Horarios de trabajo flexibles.
Modalidad de trabajo híbrida (oficina/remoto) o totalmente remota para candidatos que demuestren capacidades y condiciones remarcables.
Celebramos y promovemos la diversidad, inclusión y respeto.
Flexibilidad en el foco de tu carrera. Si te interesan otras áreas de desarrollo, nosotros vamos a facilitar y darte apoyo para que desarrolles esas habilidades.
Programa de referidos. Incentivamos la recomendación de nuevos talentos.
Requerimientos excluyentes:
Maestría en el uso de Unity Engine + C#.
2+ años de experiencia desarrollando juegos.
Muy buen manejo del idioma inglés, tanto oral como escrito.
Habilidades de programación fuertemente orientadas hacia la programación de objetos.
Experiencia con sistemas de control de versionado.
Tener un entendimiento claro de los procesos de desarrollo de un juego.
Ser proactivo, auto-organizado y orientado principalmente a la resolución de problemas.

Requerimientos no excluyentes:
Bonus
Experiencia trabajando con metodologías Ágiles.
Experiencia trabajando en VR.
Capacidad de tomar la iniciativa.
Experiencia perfilando UI y optimizando (CPU y GPU).
Conocimiento de los formatos de imágenes/texturas, su compresión y shaders.
Experiencia con C++.

Edad: No aplica

Lugar de trabajo: CABA - Hibrido/Remoto
"""

# %%
from resume import Resume

r = Resume(JOB_PROMPT_SPANISH)

# %%
""" exp = {'language': 'EN',
 'resume_section': {'title': 'Unity Developer',
  'professional_summary': 'Experienced Unity Developer with proven expertise in full-cycle game development using C#. Skilled in building game engines, prototypes, and implementing efficient code for both PC and mobile platforms. Adept at utilizing APIs, libraries, and Scriptable Objects to enhance game functionality and performance. Collaborative team player passionate about solving complex problems and delivering high-quality gaming experiences.',
  'experience': [{'position': 'Lead Programmer',
    'company': 'Fernobite',
    'location': 'Argentina',
    'start_date': '01/10/2024',
    'end_date': 'Present',
    'description': 'Developed and integrated all game and ludic features for online and offline gameplay, leveraging Scriptable Objects for versatile and future-proof code. Created internal development tools to streamline data input and testing processes. Collaborated effectively in Agile sprints, contributing to improved system efficiency and performance.'},
   {'position': 'C# Developer',
    'company': 'ABI RACHED STUDIOS',
    'location': 'Argentina',
    'start_date': '01/03/2024',
    'end_date': '01/07/2024',
    'description': "Developed and integrated the foundational structure of the game's back-end, including input systems, micro services, events, and enemy AI. Utilized Scriptable Objects for adaptable code and future content integration. Collaborated effectively in Agile sprints to enhance system efficiency and performance."},
   {'position': 'Main Programmer',
    'company': 'Freelance',
    'location': 'Argentina',
    'start_date': '01/12/2024',
    'end_date': 'Present',
    'description': 'Developed games for PC and mobile platforms for clients worldwide as a freelance programmer.'}],
  'skills': [{'name': 'Unity Development',
    'description': 'Extensive experience in developing games using Unity engine, proficient in C# scripting and game mechanics implementation.'},
   {'name': 'Scriptable Objects',
    'description': 'Expertly utilizes Scriptable Objects to create reusable and adaptable code for efficient game development and future content integration.'},
   {'name': 'Game Engine Architecture',
    'description': 'Skilled in designing and building robust game engine foundations, including core systems, input handling, and gameplay logic.'},
   {'name': 'API Integration',
    'description': 'Experienced in integrating various APIs and libraries to enhance game functionality and performance.'},
   {'name': 'Agile Development',
    'description': 'Collaborative team player with experience working in Agile sprints, contributing to efficient project delivery and continuous improvement.'}]}}
r.response = exp """
r.generate_resume()
# Out:
# chatbot message
# tools message
# {'query': 'Data Scientist with experience in Python, R, and SQL'}
# chromadb
# [('type: job\ncompany: Mouse Soluciones\nlocation: Argentina\nrole: Software Developer\nstart_date: 01/02/2020\nend_date: 01/08/2024\ndescription: Python, SQL, PostgreSQL, R. Designed and implemented custom software solutions using Python, SQL, and Firebase to address client-specific needs. User R to analyze data and process large volumes of information to do introductory data analisys and EDA (exploratory analisys) for a machine learning proyect. Cleaned and processed data using Python and R saving over 250 man hours on cleaning and loading data. Developed a web application using Django and React, enhancing user experience and engagement. Collaborated with cross-functional teams to gather requirements and deliver solutions that met client expectations. Created and maintained documentation for software development processes, ensuring knowledge transfer and project continuity.', 0.8973425626754761), ("type: contract\ncompany: Somos Feed\nlocation: Argentina\nrole: Data Architect\nstart_date: 01/07/2024\nend_date: 01/12/2024\ndescription: Python, Django, Javascript, SQLite, Pandas, Numpy, XGBoost, SKlearn, Matplot lib, Plotly. Designed and built the backend infrastructure on Django for the company to automate the process of data gathering from all its different providers. Generated the ETL pipeline to load the information onto the database from google sheet files and created the machine learning algorithm to be trained weekly on the previous week's data to estimate sales and reduce waste, genrating up to a 68% of waste reduction and increasing the benefits of the company by 30%. The solution also freed time of other data scientists in the team that were previously just cleaning data. Created a Machine Learning pipeline that auto adjust and pick the best regresor based on last's week behavior to adjust to a growing and constanly changing database. Did exploratory data analysis (EDA) and applied statistical analysis on the results to know where to look into the data and make the most impact without wasting resources and time.", 1.2056490182876587)]
# {'query': 'Experience in predictive models and Generative AI'}
# chromadb
# [('type: job\ncompany: Mouse Soluciones\nlocation: Argentina\nrole: Software Developer\nstart_date: 01/02/2020\nend_date: 01/08/2024\ndescription: Python, SQL, PostgreSQL, R. Designed and implemented custom software solutions using Python, SQL, and Firebase to address client-specific needs. User R to analyze data and process large volumes of information to do introductory data analisys and EDA (exploratory analisys) for a machine learning proyect. Cleaned and processed data using Python and R saving over 250 man hours on cleaning and loading data. Developed a web application using Django and React, enhancing user experience and engagement. Collaborated with cross-functional teams to gather requirements and deliver solutions that met client expectations. Created and maintained documentation for software development processes, ensuring knowledge transfer and project continuity.', 1.557570457458496), ("type: contract\ncompany: Somos Feed\nlocation: Argentina\nrole: Data Architect\nstart_date: 01/07/2024\nend_date: 01/12/2024\ndescription: Python, Django, Javascript, SQLite, Pandas, Numpy, XGBoost, SKlearn, Matplot lib, Plotly. Designed and built the backend infrastructure on Django for the company to automate the process of data gathering from all its different providers. Generated the ETL pipeline to load the information onto the database from google sheet files and created the machine learning algorithm to be trained weekly on the previous week's data to estimate sales and reduce waste, genrating up to a 68% of waste reduction and increasing the benefits of the company by 30%. The solution also freed time of other data scientists in the team that were previously just cleaning data. Created a Machine Learning pipeline that auto adjust and pick the best regresor based on last's week behavior to adjust to a growing and constanly changing database. Did exploratory data analysis (EDA) and applied statistical analysis on the results to know where to look into the data and make the most impact without wasting resources and time.", 1.5857983827590942)]
# {'query': 'Knowledge of supervised and unsupervised models, model evaluation, and data balancing'}
# chromadb
# [("type: contract\ncompany: Somos Feed\nlocation: Argentina\nrole: Data Architect\nstart_date: 01/07/2024\nend_date: 01/12/2024\ndescription: Python, Django, Javascript, SQLite, Pandas, Numpy, XGBoost, SKlearn, Matplot lib, Plotly. Designed and built the backend infrastructure on Django for the company to automate the process of data gathering from all its different providers. Generated the ETL pipeline to load the information onto the database from google sheet files and created the machine learning algorithm to be trained weekly on the previous week's data to estimate sales and reduce waste, genrating up to a 68% of waste reduction and increasing the benefits of the company by 30%. The solution also freed time of other data scientists in the team that were previously just cleaning data. Created a Machine Learning pipeline that auto adjust and pick the best regresor based on last's week behavior to adjust to a growing and constanly changing database. Did exploratory data analysis (EDA) and applied statistical analysis on the results to know where to look into the data and make the most impact without wasting resources and time.", 1.117605447769165), ('type: job\ncompany: Mouse Soluciones\nlocation: Argentina\nrole: Software Developer\nstart_date: 01/02/2020\nend_date: 01/08/2024\ndescription: Python, SQL, PostgreSQL, R. Designed and implemented custom software solutions using Python, SQL, and Firebase to address client-specific needs. User R to analyze data and process large volumes of information to do introductory data analisys and EDA (exploratory analisys) for a machine learning proyect. Cleaned and processed data using Python and R saving over 250 man hours on cleaning and loading data. Developed a web application using Django and React, enhancing user experience and engagement. Collaborated with cross-functional teams to gather requirements and deliver solutions that met client expectations. Created and maintained documentation for software development processes, ensuring knowledge transfer and project continuity.', 1.2688649892807007)]
# {'query': 'Experience with Azure cloud platform'}
# chromadb
# [('type: job\ncompany: Accenture\nlocation: Argentina\nrole: Data Engineer\nstart_date: 01/08/2024\nend_date: \ndescription: Python, SQL, Javascript, Google sheets. Developed and integrated AI-driven solutions for a large bank, utilizing LangChain and RAGs to enhance LLM capabilities, collaborated on the proyect with two other engineers using git and dividing tasks on sprints. Implemented voice message processing and structured data queries, improving system response accuracy. Collaborated in Agile sprints, contributing to increased system efficiency and performance. Used Data scraping techniques to gather information for my vector database (chromaDB) and deployed it on Azure using github actions with testing and CI/CD to ensure consistency on the product. Also worked on ETL pipelines to upload and generate a system to detect anomalies in the machine in order to prevent sudden breakdowns, saving over 120 man hours on cleaning and loading data.', 0.9939233064651489), ('type: job\ncompany: Turbodato\nlocation: Argentina\nrole: Data Architect\nstart_date: 01/01/2024\nend_date: 01/12/2024\ndescription: Python, SQL, Azure Database. Designed and built the startup’s backend infrastructure with a focus on scalability and automation. Developed web scraping bots to collect competitive business intelligence for clients like Itaú Bank and Cebra Jugueterías. Created interactive dashboards using Power BI, enabling real-time decision-making. Created automated tasks using azure functions to reduce the time spent on manual tasks by 80%.', 1.0803978443145752)]
# chatbot message
# chatbot message
# {'messages': [SystemMessage(content='You are BetterResume, an open-source tool that helps users create the best possible resumes optimized for ATS AI scanners.  \n\nThe user has provided a structured resume in JSON format. Your task is to **translate the content into the specified language while maintaining professional tone and accuracy**.  \n\n**Instructions:**  \n1. **Identify the target language from the `"language"` field** in the JSON.  \n2. **Translate all text fields (`title`, `professional_summary`, `experience`, `skills`) into the target language** while preserving clarity and impact.  \n3. **Do not translate company names, locations, or technical terms (e.g., "Unity Engine", "C#") unless there is a commonly accepted localized term.**  \n4. **Keep formatting unchanged** and return the translated resume as structured JSON.  \n\n### Example Input:\n```json\n{\n  "language": "ES",\n  "resume_section": {\n    "title": "Programador de Videojuegos",\n    "professional_summary": "Experienced C# developer with a strong background in game development, proficient in Unity Engine and Agile methodologies. Proven ability to develop robust architectures, integrate game features, and optimize performance. Collaborative team player with a focus on problem-solving and continuous improvement.",\n    "experience": [\n      {\n        "position": "Lead Programmer",\n        "company": "Fernobite",\n        "location": "Argentina",\n        "start_date": "October 2024",\n        "end_date": "Present",\n        "description": "Developed and integrated all game and ludic features for online and offline gameplay, utilizing Scriptable Objects to enhance code versatility. Created Development Tools within Unity for streamlined data input and testing, contributing to increased system efficiency through Agile sprints."\n      }\n    ],\n    "skills": [\n      {\n        "name": "Unity Engine",\n        "description": "Mastery of Unity Engine for game development, including scripting, UI design, and asset integration. Proficient in creating robust and scalable game architectures."\n      }\n    ]\n  }\n}```\nExpected Output (Translated to Spanish):\n```json\n{\n  "language": "ES",\n  "resume_section": {\n    "title": "Programador de Videojuegos",\n    "professional_summary": "Desarrollador de C# con experiencia en desarrollo de videojuegos, experto en Unity Engine y metodologías ágiles. Capacidad comprobada para diseñar arquitecturas robustas, integrar características de juego y optimizar el rendimiento. Jugador de equipo colaborativo con enfoque en la resolución de problemas y mejora continua.",\n    "experience": [\n      {\n        "position": "Programador Líder",\n        "company": "Fernobite",\n        "location": "Argentina",\n        "start_date": "Octubre 2024",\n        "end_date": "Presente",\n        "description": "Desarrolló e integró todas las características lúdicas y de juego para partidas en línea y fuera de línea, utilizando Scriptable Objects para mejorar la versatilidad del código. Creó herramientas de desarrollo dentro de Unity para optimizar la entrada de datos y pruebas, contribuyendo a una mayor eficiencia del sistema mediante sprints ágiles."\n      }\n    ],\n    "skills": [\n      {\n        "name": "Unity Engine",\n        "description": "Dominio de Unity Engine para el desarrollo de videojuegos, incluyendo scripting, diseño de UI e integración de assets. Experto en la creación de arquitecturas de juego robustas y escalables."\n      }\n    ]\n  }\n}```\nReturn only the translated JSON output without additional text or explanations.\n\nIf you understand, proceed with the translation.', additional_kwargs={}, response_metadata={}, id='d06ef78a-af06-4414-9392-11fb44a3b327'), HumanMessage(content='JSON: {"language": "ES", "resume_section": {"title": "Data Scientist", "professional_summary": "Highly motivated Data Scientist with 2+ years of experience in developing and implementing predictive models, specializing in machin ...
# Document successfully saved as resume_Ian_Dalton.pdf
# Document successfully saved as resume_Ian_Dalton.pdf

# %%
r.response
# Out:
# {'language': 'ES',
#  'resume_section': {'title': 'Científico de Datos',
#   'professional_summary': 'Científico de Datos altamente motivado con más de 2 años de experiencia en el desarrollo e implementación de modelos predictivos, especializado en técnicas de aprendizaje automático y plataformas en la nube. Capacidad comprobada para diseñar pipelines ETL, analizar datos y ofrecer soluciones impactantes que impulsan los resultados comerciales.',
#   'experience': [{'position': 'Arquitecto de Datos',
#     'company': 'Somos Feed',
#     'location': 'Argentina',
#     'start_date': '07/01/2024',
#     'end_date': '12/01/2024',
#     'description': 'Diseñó y construyó la infraestructura backend en Django para automatizar la recopilación de datos, lo que resultó en una reducción del 68% en el desperdicio y un aumento del 30% en los beneficios de la empresa. Desarrolló un pipeline de Aprendizaje Automático que se ajusta automáticamente para seleccionar el mejor regresor según el comportamiento de la semana pasada.'},
#    {'position': 'Ingeniero de Datos',
#     'company': 'Accenture',
#     'location': 'Argentina',
#     'start_date': '08/01/2024',
#     'end_date': 'Presente',
#     'description': 'Desarrolló e integró soluciones impulsadas por IA para un gran banco, utilizando LangChain y RAGs para mejorar las capacidades de los LLM. Implementó el procesamiento de mensajes de voz y consultas de datos estructurados, mejorando la precisión de la respuesta del sistema. Desplegó la solución en Azure utilizando acciones de github con pruebas y CI/CD.'},
#    {'position': 'Desarrollador de Software',
#     'company': 'Mouse Soluciones',
#     'location': 'Argentina',
#     'start_date': '02/01/2020',
#     'end_date': '08/01/2024',
#     'description': 'Diseñó e implementó soluciones de software personalizadas utilizando Python, SQL y Firebase. Limpió y procesó datos utilizando Python y R ahorrando más de 250 horas hombre en la limpieza y carga de datos. Desarrolló una aplicación web utilizando Django y React.'}],
#   'skills': [{'name': 'Python',
#     'description': 'Experto en el desarrollo de pipelines ETL escalables, la implementación de algoritmos de aprendizaje automático y la construcción de soluciones impulsadas por IA.'},
#    {'name': 'SQL',
#     'description': 'Experimentado en la consulta y manipulación de bases de datos para extraer información y respaldar el análisis de datos.'},
#    {'name': 'Machine Learning',
#     'description': 'Conocimiento de modelos supervisados y no supervisados, evaluación de modelos y técnicas de equilibrio de datos.'},
#    {'name': 'Cloud Computing (Azure)',
#     'description': 'Experimentado en el despliegue de modelos impulsados por IA en Azure, utilizando pipelines CI/CD para una entrega consistente del producto.'},
#    {'name': 'Django',
#     'description': 'Desarrolló infraestructura backend y aplicaciones web utilizando el framework Django.'}]}}
